# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

train_data = pd.read_csv('C:/Users/Saachi Talwar/Desktop/datasets/ccpp_training.csv')
train_data.head()
# Out:
#      # T      V       AP     RH      EP
# 0   8.58  38.38  1021.03  84.37  482.26
# 1  21.79  58.20  1017.21  66.74  446.94
# 2  16.64  48.92  1011.55  78.76  452.56
# 3  31.38  71.32  1009.17  60.42  433.44
# 4   9.20  40.03  1017.05  92.46  480.38

# %%
train_data.shape
# Out:
# (7176, 5)

# %%
train_data.describe()
# Out:
#                # T            V           AP           RH           EP
# count  7176.000000  7176.000000  7176.000000  7176.000000  7176.000000
# mean     19.629712    54.288154  1013.263032    73.275818   454.431293
# std       7.475256    12.751468     5.964863    14.625093    17.134571
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.470000    41.740000  1009.010000    63.202500   439.737500
# 50%      20.315000    52.050000  1012.910000    74.895000   451.740000
# 75%      25.720000    66.540000  1017.302500    84.925000   468.667500
# max      35.770000    81.560000  1033.300000   100.160000   495.760000

# %%
te = np.genfromtxt("C:/Users/Saachi Talwar/Desktop/datasets/ccpp_test.csv",delimiter=",")
te_df = pd.DataFrame(te, columns=train_data.columns[0:train_data.shape[1]-1])
te_df
# Out:
#         # T      V       AP     RH
# 0     11.95  42.03  1017.58  90.89
# 1     12.07  38.25  1012.67  81.66
# 2     26.91  74.99  1005.64  78.98
# 3     20.58  39.53  1005.68  62.09
# 4     16.78  37.20  1011.97  68.94
# ...     ...    ...      ...    ...
# 2387  29.49  69.71  1009.34  56.35
# 2388  27.69  65.34  1014.31  46.59
# 2389  24.32  66.25  1009.09  91.89
# 2390  23.49  42.80  1013.96  65.31
# 2391  21.76  60.27  1018.96  85.06
#
# [2392 rows x 4 columns]

# %%
te_df.shape
# Out:
# (2392, 4)

# %%
train_data[' EP'].mean()
# Out:
# 454.43129319955347

# %%
# Correlation -> Pearson's correlation
from scipy.stats import pearsonr 

for i in range(train_data.shape[1]-1):
    feature_name=train_data.columns[i]
    X = train_data[feature_name].values  
    Y = train_data[' EP']
    print(feature_name, " : " ,pearsonr(X,Y))
# Out:
# # T  :  (-0.9484570949246794, 0.0)
#  V  :  (-0.869619774014659, 0.0)
#  AP  :  (0.5198873648243959, 0.0)
#  RH  :  (0.39298781521718323, 1.1154968271568967e-263)

# %%
te_df[' EP'] = np.nan
te_df.head()
# Out:
#      # T      V       AP     RH   EP
# 0  11.95  42.03  1017.58  90.89  NaN
# 1  12.07  38.25  1012.67  81.66  NaN
# 2  26.91  74.99  1005.64  78.98  NaN
# 3  20.58  39.53  1005.68  62.09  NaN
# 4  16.78  37.20  1011.97  68.94  NaN

# %%
df=pd.concat([train_data,te_df],axis=0,ignore_index=True)
df
# Out:
#         # T      V       AP     RH      EP
# 0      8.58  38.38  1021.03  84.37  482.26
# 1     21.79  58.20  1017.21  66.74  446.94
# 2     16.64  48.92  1011.55  78.76  452.56
# 3     31.38  71.32  1009.17  60.42  433.44
# 4      9.20  40.03  1017.05  92.46  480.38
# ...     ...    ...      ...    ...     ...
# 9563  29.49  69.71  1009.34  56.35     NaN
# 9564  27.69  65.34  1014.31  46.59     NaN
# 9565  24.32  66.25  1009.09  91.89     NaN
# 9566  23.49  42.80  1013.96  65.31     NaN
# 9567  21.76  60.27  1018.96  85.06     NaN
#
# [9568 rows x 5 columns]

# %%
# Scaling the data
df_y = df.values[:,4]
del df[' EP']
df_y
# Out:
# array([482.26, 446.94, 452.56, ...,    nan,    nan,    nan])

# %%
print(np.any(np.isnan(df.values[:,0:df.shape[1]-1])))
print(np.all(np.isfinite(df.values[:0:df.shape[1]-1])))
# Out:
# False
# True

# %%
x_scaled = preprocessing.scale(df.values[:,0:df.shape[1]])
scaled_df = pd.DataFrame(x_scaled, columns = df.columns[0:df.shape[1]])
scaled_df.head(20)
# Out:
#          # T         V        AP        RH
# 0  -1.485656 -1.253287  1.308572  0.757630
# 1   0.287003  0.306455  0.665309 -0.449945
# 2  -0.404079 -0.423838 -0.287798  0.373370
# 3   1.573891  1.338938 -0.688574 -0.882837
# 4  -1.402458 -1.123440  0.638366  1.311758
# 5   0.961982  1.174465  0.003523 -1.537653
# 6  -1.364884 -1.062844  1.778390  0.388439
# 7  -1.374278 -1.004610  1.047562  0.608310
# 8   1.526924  1.202795 -0.924325 -0.640363
# 9  -0.189374  0.381216 -0.212021  0.759685
# 10  0.041434 -1.162787 -1.195438 -0.721872
# 11 -0.700640 -1.139966 -0.117720  0.356931
# 12 -0.707350 -1.069927  1.717768 -0.492412
# 13 -1.935194 -1.474421  2.184218  0.415838
# 14 -0.700640 -0.987297  1.812069  0.702834
# 15  1.363212  1.523872 -1.289739 -0.849274
# 16 -0.249760 -0.848793  1.244583 -0.343777
# 17  0.442664  0.758167  0.109611  0.562418
# 18 -0.095441 -0.441151 -0.801398  1.474093
# 19  1.121669  0.817188 -0.951268 -1.017773

# %%
df = scaled_df
df['T_T']=df['# T'] ** 2
df['V_V'] = df[' V'] ** 2
df['AP_AP'] = df[' AP'] ** 2
df['RH_RH']=df[' RH'] ** 2

df['T_V'] = df['# T'] * df[' V']
df['v_AP'] = df[' V'] * df[' AP']
df['AP_RH'] = df[' AP'] * df[' RH']
df['RH_T'] = df[' RH'] * df['# T']

df.describe()
# Out:
#                 # T             V            AP            RH           T_T  \
# count  9.568000e+03  9.568000e+03  9.568000e+03  9.568000e+03  9.568000e+03
# mean  -1.956989e-16  3.737430e-16  5.469937e-15 -3.487084e-16  1.000000e+00
# std    1.000052e+00  1.000052e+00  1.000052e+00  1.000052e+00  9.810538e-01
# min   -2.394126e+00 -2.277901e+00 -3.430019e+00 -3.270589e+00  2.729561e-08
# 25%   -8.240958e-01 -9.888705e-01 -7.003615e-01 -6.836860e-01  2.104670e-01
# 50%    9.309729e-02 -1.751604e-01 -5.373067e-02  1.141150e-01  6.719732e-01
# 75%    8.143721e-01  9.627745e-01  6.737290e-01  7.891378e-01  1.554501e+00
# max    2.342804e+00  2.144779e+00  3.374760e+00  1.839173e+00  5.731842e+00
#
#                 V_V         AP_AP         RH_RH          T_V         v_AP  \
# count  9.568000e+03  9.568000e+03  9.568000e+03  9568.000000  9568.000000
# mean   1.000000e+00  1.000000e+00  1.000000e+00     0.844107    -0.413502
# ...

# %%
df_=pd.DataFrame(df_y,columns=train_data.columns[train_data.shape[1]-1:train_data.shape[1]])
df = scaled_df.join(df_)
df.head(10)
# Out:
#         # T         V        AP        RH       T_T       V_V     AP_AP  \
# 0 -1.485656 -1.253287  1.308572  0.757630  2.207173  1.570728  1.712362
# 1  0.287003  0.306455  0.665309 -0.449945  0.082371  0.093915  0.442637
# 2 -0.404079 -0.423838 -0.287798  0.373370  0.163280  0.179638  0.082827
# 3  1.573891  1.338938 -0.688574 -0.882837  2.477133  1.792756  0.474134
# 4 -1.402458 -1.123440  0.638366  1.311758  1.966887  1.262116  0.407512
# 5  0.961982  1.174465  0.003523 -1.537653  0.925409  1.379368  0.000012
# 6 -1.364884 -1.062844  1.778390  0.388439  1.862909  1.129638  3.162671
# 7 -1.374278 -1.004610  1.047562  0.608310  1.888639  1.009240  1.097387
# 8  1.526924  1.202795 -0.924325 -0.640363  2.331498  1.446717  0.854376
# 9 -0.189374  0.381216 -0.212021  0.759685  0.035863  0.145325  0.044953
#
#       RH_RH       T_V      v_AP     AP_RH      RH_T      EP
# 0  0.574003  1.861953 -1.640017  0.991414 -1.125577  482.26
# ...

# %%
train_data = df[0:7176]
te_df = df[7176:9568]
train_data.head(10)
# Out:
#         # T         V        AP        RH       T_T       V_V     AP_AP  \
# 0 -1.485656 -1.253287  1.308572  0.757630  2.207173  1.570728  1.712362
# 1  0.287003  0.306455  0.665309 -0.449945  0.082371  0.093915  0.442637
# 2 -0.404079 -0.423838 -0.287798  0.373370  0.163280  0.179638  0.082827
# 3  1.573891  1.338938 -0.688574 -0.882837  2.477133  1.792756  0.474134
# 4 -1.402458 -1.123440  0.638366  1.311758  1.966887  1.262116  0.407512
# 5  0.961982  1.174465  0.003523 -1.537653  0.925409  1.379368  0.000012
# 6 -1.364884 -1.062844  1.778390  0.388439  1.862909  1.129638  3.162671
# 7 -1.374278 -1.004610  1.047562  0.608310  1.888639  1.009240  1.097387
# 8  1.526924  1.202795 -0.924325 -0.640363  2.331498  1.446717  0.854376
# 9 -0.189374  0.381216 -0.212021  0.759685  0.035863  0.145325  0.044953
#
#       RH_RH       T_V      v_AP     AP_RH      RH_T      EP
# 0  0.574003  1.861953 -1.640017  0.991414 -1.125577  482.26
# ...

# %%
del te_df[' EP']
te_df.head(10)
# Out:
#            # T         V        AP        RH       T_T       V_V     AP_AP  \
# 7176 -1.033433 -0.966049  0.727615  1.204220  1.067984  0.933250  0.529423
# 7177 -1.017330 -1.263517 -0.099197  0.572007  1.034961  1.596476  0.009840
# 7178  0.974059  1.627750 -1.283003  0.388439  0.948791  2.649571  1.646096
# 7179  0.124632 -1.162787 -1.276267 -0.768449  0.015533  1.352074  1.628858
# 7180 -0.385292 -1.346147 -0.217072 -0.299255  0.148450  1.812113  0.047120
# 7181  0.376911  0.329277 -0.296217 -0.189662  0.142062  0.108423  0.087745
# 7182 -1.528597 -1.050253  2.015825  1.089833  2.336608  1.103031  4.063550
# 7183  0.175625  1.194139 -0.373678  0.638448  0.030844  1.425968  0.139635
# 7184 -1.970084 -1.075435  1.288365  1.436420  3.881231  1.156561  1.659885
# 7185  0.799611  1.053274 -0.680154 -0.311584  0.639378  1.109387  0.462610
#
#          RH_RH       T_V      v_AP     AP_RH      RH_T
# 7176  1.450147  0.998347 -0.702912  0.876209 -1.244481
# ...

# %%
te_df = te_df.reset_index(drop = True)
te_df.head(10)
# Out:
#         # T         V        AP        RH       T_T       V_V     AP_AP  \
# 0 -1.033433 -0.966049  0.727615  1.204220  1.067984  0.933250  0.529423
# 1 -1.017330 -1.263517 -0.099197  0.572007  1.034961  1.596476  0.009840
# 2  0.974059  1.627750 -1.283003  0.388439  0.948791  2.649571  1.646096
# 3  0.124632 -1.162787 -1.276267 -0.768449  0.015533  1.352074  1.628858
# 4 -0.385292 -1.346147 -0.217072 -0.299255  0.148450  1.812113  0.047120
# 5  0.376911  0.329277 -0.296217 -0.189662  0.142062  0.108423  0.087745
# 6 -1.528597 -1.050253  2.015825  1.089833  2.336608  1.103031  4.063550
# 7  0.175625  1.194139 -0.373678  0.638448  0.030844  1.425968  0.139635
# 8 -1.970084 -1.075435  1.288365  1.436420  3.881231  1.156561  1.659885
# 9  0.799611  1.053274 -0.680154 -0.311584  0.639378  1.109387  0.462610
#
#       RH_RH       T_V      v_AP     AP_RH      RH_T
# 0  1.450147  0.998347 -0.702912  0.876209 -1.244481
# 1  0.327192  1.285415  0.125337 -0.056741 -0.581920
# ...

# %%
tr_df = train_data.values
tr_df
# Out:
# array([[-1.48565576e+00, -1.25328692e+00,  1.30857232e+00, ...,
#          9.91413518e-01, -1.12557723e+00,  4.82260000e+02],
#        [ 2.87002787e-01,  3.06455193e-01,  6.65309346e-01, ...,
#         -2.99352761e-01, -1.29135532e-01,  4.46940000e+02],
#        [-4.04079084e-01, -4.23837783e-01, -2.87797566e-01, ...,
#         -1.07455070e-01, -1.50871138e-01,  4.52560000e+02],
#        ...,
#        [ 1.36186993e+00,  1.18312154e+00, -6.56579216e-01, ...,
#          3.85370083e-01, -7.99330707e-01,  4.37650000e+02],
#        [-4.40310561e-01, -4.56725914e-04,  7.88236563e-01, ...,
#         -5.22574144e-01,  2.91910989e-01,  4.59970000e+02],
#        [ 1.40346903e+00,  6.08645389e-01, -4.32615931e-01, ...,
#          7.51146773e-01, -2.43682944e+00,  4.44420000e+02]])

# %%
test_data = te_df.values
test_data
# Out:
# array([[-1.03343325, -0.96604884,  0.72761492, ..., -0.70291155,
#          0.87620871, -1.24448137],
#        [-1.01733038, -1.26351731, -0.09919691, ...,  0.12533701,
#         -0.05674134, -0.58192028],
#        [ 0.97405894,  1.62775035, -1.28300284, ..., -2.08840832,
#         -0.49836876,  0.3783628 ],
#        ...,
#        [ 0.62650514,  0.93995287, -0.70204545, ..., -0.65988963,
#         -0.89350436,  0.79736302],
#        [ 0.5151269 , -0.90545341,  0.11803064, ..., -0.10687125,
#         -0.06466825, -0.2822348 ],
#        [ 0.28297707,  0.4693546 ,  0.95999788, ...,  0.45057942,
#          0.7726944 ,  0.22776592]])

# %%
training_data = np.genfromtxt('C:/Users/Saachi Talwar/Desktop/datasets/ccpp_training.csv', delimiter = ',')
training_data.shape
# Out:
# (7176, 5)

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(training_data)
scaler.transform(training_data)
# Out:
# array([[-1.47827466e+00, -1.24764165e+00,  1.30221067e+00,
#          7.58624590e-01,  1.62423942e+00],
#        [ 2.89012041e-01,  3.06797549e-01,  6.61749044e-01,
#         -4.46921842e-01, -4.37233891e-01],
#        [-3.99975582e-01, -4.21012529e-01, -2.87207194e-01,
#          3.75010552e-01, -1.09219167e-01],
#        ...,
#        [ 1.36062192e+00,  1.18048335e+00, -6.54382840e-01,
#         -5.83682640e-01, -9.79450400e-01],
#        [-4.36097263e-01,  9.29089763e-04,  7.84140927e-01,
#         -6.59584883e-01,  3.23269996e-01],
#        [ 1.40209496e+00,  6.07960340e-01, -4.31394890e-01,
#         -1.73110573e+00, -5.84315226e-01]])

# %%
def step_grad(points, learn_rate, M):
    N = points.shape[0]
    num_col = points.shape[1]
    
    new_M = np.zeros(num_col)
    
    for i in range(N):
        x = points[i, 0:num_col-1]
        x = np.append(x, 1)
        y = points[i, num_col-1]
        for j in range(num_col):
            new_M[j] += (-2/N) * (y - (M * x).sum()) * x[j]
        M = M - (learn_rate * new_M)
        
    #print (M.shape)
    return M

# %%
def gd(points, learn_rate, num_iter):
    num_col = points.shape[1]
    M = np.zeros(num_col)
    
    for i in range(num_iter):
        M = step_grad(points, learn_rate, M)
        if i % 100== 0:
            print(i, "Cost= ", cost(points, M))
    print(i, "Cost= ", cost(points, M))
    return M

# %%
def cost(points, M):
    total_cost = 0
    
    N = points.shape[0]
    num_col = points.shape[1]
    
    for i in range(N):
        x = points[i,0:num_col-1]
        x = np.append(x, 1)
        y = points[i,num_col-1]
        total_cost += (y - (M * x).sum()) ** 2
        
    total_cost = (1/N) * total_cost
    return total_cost

# %%
def run():
    learning_rate = 0.0001
    num_iterations = 1000
    m = gd(tr_df, learning_rate, num_iterations)
    return m[0:4], m[4]

# %%
m,c = run()
print(m,c)
# Out:
# 0 Cost=  150864.9483966277
# 100 Cost=  19.725650872824964
# 200 Cost=  18.258389028620996
# 300 Cost=  18.253438374166862
# 400 Cost=  18.25387279216561
# 500 Cost=  18.25391753199487
# 600 Cost=  18.253921503626653
# 700 Cost=  18.253921852040513
# 800 Cost=  18.25392188257409
# 900 Cost=  18.25392188524961
# 999 Cost=  18.253921885483297
# [-13.5139114   -3.69193227   0.75316022  -1.79868287] 0.8466467820555564

# %%
scaler.fit(test_data)
scaler.transform(test_data)
# Out:
# array([[-1.05179958, -0.9803295 ,  0.73940279, ..., -0.32673632,
#          0.83227148, -0.72285742],
#        [-1.03554677, -1.28089884, -0.09850361, ...,  0.54423715,
#         -0.15830913, -0.05580758],
#        [ 0.97438468,  1.64050792, -1.29819445, ..., -1.78370346,
#         -0.62721693,  0.91098128],
#        ...,
#        [ 0.62359476,  0.94554072, -0.70944148, ..., -0.28149513,
#         -1.046761  ,  1.33282017],
#        [ 0.51117945, -0.91910241,  0.1216388 , ...,  0.30005051,
#         -0.1667257 ,  0.24590823],
#        [ 0.27686804,  0.47003684,  0.97490397, ...,  0.88625707,
#          0.72236285,  0.75936413]])

# %%
from sklearn.ensemble import GradientBoostingRegressor
x = tr_df[:, :-1]
y = tr_df[:, -1]
reg = GradientBoostingRegressor()
reg.fit(x,y)
y_predict = reg.predict(test_data)
np.savetxt("ccpp_pred.csv", y_predict, delimiter=',')

# %%
def predict(x, m, c):
    N = x.shape[0]
    y = np.zeros(N)   
    for i in range(N):
        X = x[i,:]
        y[i] = (m * X).sum() + c      
    return y

# %%
x_test = test_data
y_pred = predict(x_test, m, c)
y_pred

# %%
np.savetxt("ccpp_preds", y_pred, delimiter = ',')
